# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import seaborn as sns

# %%
pip install seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.9 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/294.9 kB 262.6 kB/s eta 0:00:02
#    ---------- ---------------------------- 81.9/294.9 kB 573.4 kB/s eta 0:00:01
#    ---------------------- --------------- 174.1/294.9 kB 958.1 kB/s eta 0:00:01
#    -------------------------------------- - 286.7/294.9 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 294.9/294.9 kB 1.2 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\DELL\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
#load data from the csv file
csv_file_path='Election.csv'
df= pd.read_csv(csv_file_path, encoding='latin1')

# %%
df
# Out:
#           Date              State            Lokshabha Seat Name  \
# 0   19-04-2024            Manipur                    Thamanpokpi
# 1   19-04-2024            Manipur                  Inner Manipur
# 2   19-04-2024  Arunachal Pradesh                 Arunachal West
# 3   26-04-2024          Karnataka                 Chamarajanagar
# 4   26-04-2024          Rajasthan                         Barmer
# 5   26-04-2024          Rajasthan                          Ajmer
# 6   26-04-2024      Uttar Pradesh                      Ghaziabad
# 7   07-05-2024             Gujrat                          Dahod
# 8   07-05-2024     Madhya Pradesh                         Bhopal
# 9   07-05-2024     Madhya Pradesh                          Betul
# 10  07-05-2024     Madhya Pradesh                          Harda
# 11  07-05-2024      Uttar Pradesh                        Sambhal
# 12  07-05-2024      Uttar Pradesh                      Firzobaad
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  39 non-null     object
#  1   State                 38 non-null     object
#  2   Lokshabha Seat Name   39 non-null     object
#  3   Incident Description  39 non-null     object
#  4   Action taken          24 non-null     object
#  5   Location of Incident  22 non-null     object
#  6   Coordinates           16 non-null     object
#  7   Source news article   36 non-null     object
# dtypes: object(8)
# memory usage: 2.6+ KB

# %%
df.isnull().sum()
# Out:
# Date                     0
# State                    1
# Lokshabha Seat Name      0
# Incident Description     0
# Action taken            15
# Location of Incident    17
# Coordinates             23
# Source news article      3
# dtype: int64

# %%
df.shape
# Out:
# (39, 8)

# %%
df.drop("Date",axis=1)
# Out:
#                 State            Lokshabha Seat Name  \
# 0             Manipur                    Thamanpokpi
# 1             Manipur                  Inner Manipur
# 2   Arunachal Pradesh                 Arunachal West
# 3           Karnataka                 Chamarajanagar
# 4           Rajasthan                         Barmer
# 5           Rajasthan                          Ajmer
# 6       Uttar Pradesh                      Ghaziabad
# 7              Gujrat                          Dahod
# 8      Madhya Pradesh                         Bhopal
# 9      Madhya Pradesh                          Betul
# 10     Madhya Pradesh                          Harda
# 11      Uttar Pradesh                        Sambhal
# 12      Uttar Pradesh                      Firzobaad
# 13      Uttar Pradesh                      Firzobaad
# 14      Uttar Pradesh                       Mainpuri
# 15      Uttar Pradesh                        Sambhal
# 16      Uttar Pradesh                      Moradabad
# ...

# %%
df['Checking'] = np.random.randint(low=0, high=100, size=len(df))

# %%
df['Random'] = np.random.randint(low=0, high=100, size=len(df))

# %%
df
# Out:
#           Date              State            Lokshabha Seat Name  \
# 0   19-04-2024            Manipur                    Thamanpokpi
# 1   19-04-2024            Manipur                  Inner Manipur
# 2   19-04-2024  Arunachal Pradesh                 Arunachal West
# 3   26-04-2024          Karnataka                 Chamarajanagar
# 4   26-04-2024          Rajasthan                         Barmer
# 5   26-04-2024          Rajasthan                          Ajmer
# 6   26-04-2024      Uttar Pradesh                      Ghaziabad
# 7   07-05-2024             Gujrat                          Dahod
# 8   07-05-2024     Madhya Pradesh                         Bhopal
# 9   07-05-2024     Madhya Pradesh                          Betul
# 10  07-05-2024     Madhya Pradesh                          Harda
# 11  07-05-2024      Uttar Pradesh                        Sambhal
# 12  07-05-2024      Uttar Pradesh                      Firzobaad
# ...

# %%
plt.figure(figsize=(12, 8))
# sns.barplot(x='Lokshabha Seat Name', y='Number of Votes', data=df, palette='pastel')
sns.barplot(x='Checking',y='Random',data=df, palette='pastel')
# plt.xticks(rotation=90)
plt.title('Indian Election 2024')
plt.grid(axis='y')
plt.xlabel('Political Parties')
plt.ylabel('Number of Votes')
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_21248\439150592.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Checking',y='Random',data=df, palette='pastel')
